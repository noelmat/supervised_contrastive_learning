# %%
# !mkdir /root/.kaggle
# !mv kaggle.json /root/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json
# !pip install kaggle --upgrade
# Out:
# ...
#      |████████████████████████████████| 59 kB 273 kB/s eta 0:00:011
# ...
#      |████████████████████████████████| 78 kB 265 kB/s eta 0:00:01
# ...
#   Created wheel for kaggle: filename=kaggle-1.5.10-py3-none-any.whl size=73269 sha256=171e234338ff7aeb4c107352106d17c7a41c6b3c5a86eea2f706c9abb7dc976b
#   Stored in directory: /root/.cache/pip/wheels/a6/c1/5e/2b235e19b52c15ad35812881f8de4461399907e219c03bf7b5
# ...
#   Created wheel for python-slugify: filename=python_slugify-4.0.1-py2.py3-none-any.whl size=6769 sha256=a7c03144e01f60adb4e1463dba7b53ea78846aec67d0831d38e9a41c2d548dfc
#   Stored in directory: /root/.cache/pip/wheels/91/4d/4f/e740a68c215791688c46c4d6251770a570e8dfea91af1acb5c
# Successfully built kaggle python-slugify
# ...

# %%
# !kaggle competitions download -c cassava-leaf-disease-classification
# !unzip cassava-leaf-disease-classification.zip
# Out:
# ...
# 100%|█████████████████████████████████████▉| 5.76G/5.76G [03:11<00:00, 48.5MB/s]
# 100%|██████████████████████████████████████| 5.76G/5.76G [03:11<00:00, 32.2MB/s]
# Archive:  cassava-leaf-disease-classification.zip
#   inflating: label_num_to_disease_map.json
#   inflating: sample_submission.csv
#   inflating: test_images/2216849948.jpg
#   inflating: test_tfrecords/ld_test00-1.tfrec
#   inflating: train.csv
#   inflating: train_images/1000015157.jpg
#   inflating: train_images/1000201771.jpg
#   inflating: train_images/100042118.jpg
#   inflating: train_images/1000723321.jpg
#   inflating: train_images/1000812911.jpg
#   inflating: train_images/1000837476.jpg
#   inflating: train_images/1000910826.jpg
#   inflating: train_images/1001320321.jpg
#   inflating: train_images/1001723730.jpg
#   inflating: train_images/1001742395.jpg
#   inflating: train_images/1001749118.jpg
#   inflating: train_images/100204014.jpg
#   inflating: train_images/1002088496.jpg
# ...

# %%
from fastai.vision.all import *

# %%
from IPython.display import display, HTML

# %%
path = Path('.')

# %%
path_img = path/'train_images'

# %%
path_img.ls()
# Out:
# (#21397) [Path('train_images/1000015157.jpg'),Path('train_images/1000201771.jpg'),Path('train_images/100042118.jpg'),Path('train_images/1000723321.jpg'),Path('train_images/1000812911.jpg'),Path('train_images/1000837476.jpg'),Path('train_images/1000910826.jpg'),Path('train_images/1001320321.jpg'),Path('train_images/1001723730.jpg'),Path('train_images/1001742395.jpg')...]

# %%
train_df = pd.read_csv(path/'train.csv')
train_df.head()

with open(path/'label_num_to_disease_map.json') as f:
    label_dict = json.load(f)

label_dict = {int(k):v for k,v in label_dict.items()}

train_df['label'].value_counts(normalize=True).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import StratifiedKFold

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
splits = {}

for i,(tr_idx,val_idx) in enumerate(cv.split(train_df, train_df['label'])):
    splits[i] = [tr_idx, val_idx]

# %%
df = train_df.set_index('image_id')
labels = df.to_dict()['label']

# %%
def get_label(labels, x):
    x = Path(x)
    return labels[x.name]

fn = train_df.iloc[0,0]

# %%
# %%time
get_label(labels,path/'train_images'/fn)
# Out:
# CPU times: user 76 µs, sys: 9 µs, total: 85 µs
# Wall time: 91.8 µs
# 0

# %%
def get_splits(FOLD, x):
    return splits[FOLD]

def get_data(labels, bs=64, presize=500, resize=384):
    tfms = [Rotate(90), Warp(magnitude=0.3),Zoom(min_zoom=0.9, max_zoom=1.3), Brightness(max_lighting=0.6), Flip(), Contrast(0.4), Resize(resize)]
    comp = setup_aug_tfms(tfms)
    return DataBlock(blocks=(ImageBlock, CategoryBlock),
        get_items=lambda p: get_image_files(p),
        get_y=partial(get_label, labels),
        splitter=partial(get_splits, 0),
        item_tfms=[Resize(presize)],
        batch_tfms=[*comp, Normalize.from_stats(*imagenet_stats)]).dataloaders(path/'train_images',bs=bs,num_workers=8, shuffle_train=False)

# %%
dls = get_data(labels, bs=128, resize=224)

# %%
dls.show_batch()

# %%
def normalize(x):
    return F.normalize(x, p=2, dim=0)

# %%
class Model(Module):
    def __init__(self, pretrained=True):
        self.base_model = nn.Sequential(*list(models.resnet18(pretrained=pretrained).children())[:-1])
        self.proj = nn.Sequential(
            nn.Linear(512, 2048), 
            nn.ReLU(),
            nn.Linear(2048, 128)
        )
    
    def forward(self, x):
        enc = self.base_model(x)
        norm_enc = normalize(enc).squeeze()
        proj = self.proj(norm_enc)
        norm_proj = normalize(proj)
        return {
            'encs': enc,
            'norm_encs': norm_enc,
            'proj': proj,
            'norm_proj': norm_proj
        }

# %%
tau = 1

# %%
def supconloss(out, y):
    tot_loss = 0
    y_hat = out['norm_proj']
    for i in range(y.shape[0]):
        p = torch.where(y == y[i])[0]
        p = torch.where(p != i)[0]
        P_i = len(p)

        a = torch.where(y != y[i])[0]
#         import pdb
#         pdb.set_trace()
        numerator = (y_hat[i][None, :] @ y_hat[p].T)
        numerator = (numerator/tau).exp()

        try:
            if torch.isinf(numerator).item():
                import pdb
                pdb.set_trace()
        except:
            pass
        deno = ((y_hat[i][None, :] @ y_hat[a].T)/tau).exp().sum()
        loss = (numerator/deno).log().sum()
        loss = loss * -1/(P_i+1)
        tot_loss += loss    
        
    return tot_loss

# %%
class SupConLearner(Learner):
    def all_batches(self):
        self.n_iter = len(self.dl)
        self.dl1 = self.dl
        self.dl2 = self.dl
        for o in enumerate(zip(self.dl1, self.dl2)):
            self.one_batch(*o)
            
    def _split(self, b):
        i = getattr(self.dls, 'n_inp', 1 if len(b)==1 else len(b)-1)
        b1 = b[0]
        b2 = b[1]
        
        xb, yb = b1[:i][0],b1[i:][0]
        self.xb = tuple([torch.cat((xb,b2[:i][0]))])
        self.yb = tuple([torch.cat((yb,b2[i:][0]))])

# %%
learner = SupConLearner(dls, Model(), loss_func=supconloss)

# %%
learner.model.base_model.requires_grad_(False)
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
learner.lr_find(num_it=200, end_lr=10)
# Out:
# SuggestedLRs(lr_min=0.012022644281387329, lr_steep=0.019054606556892395)

# %%
learner.fit_one_cycle(10, 2e-3)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/10 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
# ...
